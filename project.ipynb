# %% [markdown]
# # CAPTCHA Recognition

# %%
import os
import numpy as np
from matplotlib import pyplot
from matplotlib import image
# %matplotlib inline

# %%
filenames = os.listdir('./archive')
labels = list(map(lambda x: x.split('.')[0], filenames))
images = np.array([image.imread(f"./archive/{x}") for x in filenames])
images.shape
# Out:
# (113062, 40, 150, 3)

# %%
index = 100
pyplot.imshow(images[index])
pyplot.show()
labels[index]
# Out:
# 'k73yv'
